# %%
# !rm -r Geometric-Deep-Learning/
# Out:
# rm: cannot remove 'Geometric-Deep-Learning/': No such file or directory

# %%
#!pip install Rtree trimesh
# !pip install open3d

# %%
# !git clone https://github.com/VMijangos/Geometric-Deep-Learning/
# Out:
# Cloning into 'Geometric-Deep-Learning'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 43 (delta 18), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (43/43), done.

# %%
import sys
sys.path.insert(1, 'Geometric-Deep-Learning/Random_knots/')

# %%
from knots_generator import knots
import numpy as np
import matplotlib.pyplot as plt
from knots_generator import knots
from points_cloud import knot_points_cloud
import plotly.graph_objects as go

# %%
knot_generator = knots(points=2000, noise=0.1, sc=10)
knot_generator.create_bars_random_knot(1,1,2,genus=2)
knot_generator.visualize_circle()
knot_generator.plot_knot()

# %%
pcloud = knot_points_cloud(knot_generator.knot)
#pcloud.plot_fat_knot()

# %%
pcloud.create_fat_knot(num_circ=10)
pcloud.plot_frenet_serret(arrow_length=0.07)

# %%
pcloud.plot_fat_knot()

# %%
print(pcloud.fat_knot.shape)
# Out:
# (20000, 3)

# %%
plot_fat = [go.Scatter3d(x=pcloud.fat_knot[:,0], y=pcloud.fat_knot[:,1], z=pcloud.fat_knot[:,2], mode='markers',
                     marker=dict(size=1, color='red') )]

fig = go.Figure(data=plot_fat)
fig.update_layout(autosize=False, width=1000, height=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="049384a1-fb94-4974-b502-7685c59ecb92" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("049384a1-fb94-4974-b502-7685c59ecb92")) {
#                     Plotly.newPlot(
#                         '049384a1-fb94-4974-b502-7685c59ecb92',
#                         [{"marker": {"color": "red", "size": 1}, "mode": "markers", "type": "scatter3d", "x": [-0.6944909971226866, -0.6831514562466786, -0.6732017271349304, -0.6684422681292755, -0.6706910308018124, -0.6790890642442639, -0.6904286051202718, -0.70037833423202, -0.7051377932376749, -0.7028890305651381, -0.6924077952186645, -0.6810507853691161, -0.6711342018528892, -0.6664458425209054, -0.66877650128651, -0.6772359457174197, -0.6885929555669681, -0.698509539083195, -0.7031978984151788, -0.7008672396495742, -0.690151266983222, -0.6787624014616626, -0.6689259294771395, -0.6643990489983546, -0.6669108745051952, -0.6755019740278573, -0.6868908395494168, -0.6967273115339399, -0.7012541920127248, -0.6987423665058842, -0.6876742371649182, -0.6762505891661665, -0.6665663267430781, -0.6623205089852992, -0.6651348939662635, -0.6739344822806698, -0.6853581302794214, -0.6950423927025098, -0.6992882104602888, -0.6964738254793245, -0.6851304416719509, -0.6736817471148557, -0.6641709269406195, -0.6602307911949122, -0.6633663378123057, -0.6723798945582654, -0.6838285891153606, -0.6933394092895968, -0.6972795450353041, -0.6941439984179106, -0.6825334251680854, -0.6710707710257209, -0.6617503181463946, -0.6581